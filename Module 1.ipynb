# %% [markdown]
# # 1

# %%
# !pip install -U agno groq yfinance python-dotenv

import os
from agno.agent import Agent
from agno.models.groq import Groq
from agno.tools.yfinance import YFinanceTools
os.environ["GROQ_API_KEY"] = "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"

agent = Agent(
    model=Groq(id="openai/gpt-oss-20b"),
    tools=[
        YFinanceTools(
            enable_stock_price=True,
            enable_company_info=True,
            enable_analyst_recommendations=True,
            enable_company_news=True
        )
    ],

    instructions=[
        "Use tables whenever possible.",
        "Generate a professional financial report.",
        "Include current stock price.",
        "Include company information.",
        "Include analyst recommendations.",
        "Include recent company news.",
        "Give a concise summary."
    ],

    markdown=True
)

agent.print_response(
    "Generate a detailed report on NVIDIA (NVDA)",
    stream=True
)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: agno in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (3.0.1)
# Requirement already satisfied: groq in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (1.7.0)
# Requirement already satisfied: yfinance in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (1.7.0)
# Requirement already satisfied: python-dotenv in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (1.2.3)
# Requirement already satisfied: agnoctl>=0.2.0 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from agno) (0.2.0)
# Requirement already satisfied: docstring-parser in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from agno) (0.18.0)
# Requirement already satisfied: h11>=0.16.0 in C:\ProgramData\anaconda3\Lib\site-packages (from agno) (0.16.0)
# Requirement already satisfied: httpx[http2] in C:\ProgramData\anaconda3\Lib\site-packages (from agno) (0.28.1)
# Requirement already satisfied: packaging in C:\ProgramData\anaconda3\Lib\site-packages (from agno) (25.0)
# Requirement already satisfied: pydantic-settings in C:\ProgramData\anaconda3\Lib\site-packages (from agno) (2.12.0)
# Requirement already satisfied: pydantic in C:\ProgramData\anaconda3\Lib\site-packages (from agno) (2.12.4)
# Requirement already satisfied: pyyaml in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from agno) (6.0.3)
# Requirement already satisfied: rich in C:\ProgramData\anaconda3\Lib\site-packages (from agno) (14.2.0)
# Requirement already satisfied: typing-extensions in C:\ProgramData\anaconda3\Lib\site-packages (from agno) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\ProgramData\anaconda3\Lib\site-packages (from groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\ProgramData\anaconda3\Lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: sniffio in C:\ProgramData\anaconda3\Lib\site-packages (from groq) (1.3.0)
# Requirement already satisfied: idna>=2.8 in C:\ProgramData\anaconda3\Lib\site-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in C:\ProgramData\anaconda3\Lib\site-packages (from httpx[http2]->agno) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\ProgramData\anaconda3\Lib\site-packages (from httpx[http2]->agno) (1.0.9)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic->agno) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic->agno) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic->agno) (0.4.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from yfinance) (4.15.0)
# Requirement already satisfied: curl_cffi>=0.15 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from yfinance) (0.16.2)
# Requirement already satisfied: lxml>=4.9.0 in C:\ProgramData\anaconda3\Lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: multitasking>=0.0.7 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: numpy>=1.16.5 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from yfinance) (2.5.2)
# Requirement already satisfied: pandas>=1.3.0 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from yfinance) (3.0.5)
# Requirement already satisfied: peewee>=3.16.2 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: platformdirs>=2.0.0 in C:\ProgramData\anaconda3\Lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: protobuf>=3.19.0 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from yfinance) (7.36.0)
# Requirement already satisfied: pytz>=2022.5 in C:\ProgramData\anaconda3\Lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: requests>=2.31 in C:\ProgramData\anaconda3\Lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: websockets>=13.0 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from yfinance) (17.0.1)
# Requirement already satisfied: questionary<3,>=2.1.1 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from agnoctl>=0.2.0->agno) (2.1.1)
# Requirement already satisfied: typer in C:\ProgramData\anaconda3\Lib\site-packages (from agnoctl>=0.2.0->agno) (0.20.0)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from questionary<3,>=2.1.1->agnoctl>=0.2.0->agno) (3.0.53)
# Requirement already satisfied: wcwidth>=0.1.4 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from prompt_toolkit<4.0,>=2.0->questionary<3,>=2.1.1->agnoctl>=0.2.0->agno) (0.8.2)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: cffi>=2.0.0 in C:\ProgramData\anaconda3\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: pycparser in C:\ProgramData\anaconda3\Lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from pandas>=1.3.0->yfinance) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: h2<5,>=3 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from httpx[http2]->agno) (4.4.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from h2<5,>=3->httpx[http2]->agno) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.2 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from h2<5,>=3->httpx[http2]->agno) (4.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from rich->agno) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\ProgramData\anaconda3\Lib\site-packages (from rich->agno) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\ProgramData\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich->agno) (0.1.2)
# Requirement already satisfied: click>=8.0.0 in C:\Users\comps\AppData\Roaming\Python\Python313\site-packages (from typer->agnoctl>=0.2.0->agno) (8.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from typer->agnoctl>=0.2.0->agno) (1.5.4)
# Requirement already satisfied: colorama in C:\ProgramData\anaconda3\Lib\site-packages (from click>=8.0.0->typer->agnoctl>=0.2.0->agno) (0.4.6)
# Output()
# ERROR    Error calling Groq API: Error code: 413 - {'error': {'message': 'Request too large for model
#          `openai/gpt-oss-20b` in organization `org_01m10pkaj6ej5tk0n62v6rr29w` service tier `on_demand` on tokens
#          per minute (TPM): Limit 8000, Requested 11397, please reduce your message size and try again. Need more
#          tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code':
#          'rate_limit_exceeded'}}
# ERROR    Non-retryable model provider error: {"error":{"message":"Request too large for model `openai/gpt-oss-20b`
#          in organization `org_01m10pkaj6ej5tk0n62v6rr29w` service tier `on_demand` on tokens per minute (TPM):
#          Limit 8000, Requested 11397, please reduce your message size and try again. Need more tokens? Upgrade to
#          Dev Tier today at
#          https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
# ERROR    Error in Agent run: {"error":{"message":"Request too large for model `openai/gpt-oss-20b` in organization
#          `org_01m10pkaj6ej5tk0n62v6rr29w` service tier `on_demand` on tokens per minute (TPM): Limit 8000,
#          Requested 11397, please reduce your message size and try again. Need more tokens? Upgrade to Dev Tier
#          today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# # 2A

# %%
from groq import Groq

client = Groq(
    api_key="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"
)

question = "Explain Agentic AI in one sentence."

answer = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role":"user","content":question}
    ]
)

first_response = answer.choices[0].message.content

print("Initial Answer:")
print(first_response)

reflection = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role":"user",
            "content":f"""
Review and improve this answer:

{first_response}

Make it clearer for beginners.
"""
        }
    ]
)

print("\nImproved Answer:")
print(reflection.choices[0].message.content)
# Out:
# Initial Answer:
# Agentic AI is artificial intelligence that possesses autonomy, self‑directed decision‑making, and goal‑oriented behavior, enabling it to act independently and adaptively to achieve objectives.
#
# Improved Answer:
# **Agentic AI in plain language**
#
# Agentic AI is a kind of artificial intelligence that can **act on its own**.
# Instead of just following a fixed set of instructions, it can:
#
# 1. **Decide what to do next** – it chooses actions by itself rather than just reacting to a command.
# 2. **Work toward a goal** – it has a clear aim (e.g., “reach the destination,” “sell the product”) and keeps adjusting its plan to reach that aim.
# 3. **Learn and adapt** – if something changes in its environment, it changes its behavior to keep working toward the goal.
#
# Think of it like a helpful robot or virtual assistant that can:
#
# - **Plan its route** to avoid traffic and get you to work on time.
# - **Suggest the best products** to buy based on your past preferences.
# - **Play a game** and improve its strategy over time.
#
# In short, agentic AI is the “self‑directed” type of smart software that can think, plan, and act independently to accomplish tasks.

# %% [markdown]
# # 2B

# %%
from groq import Groq

client = Groq(
    api_key="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"
)

response = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role":"user",
            "content":"""
Goal:
Organize a college technical fest.

Create a detailed step-by-step plan.
"""
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# ## 📅 Detailed Step‑by‑Step Plan for Organizing a College Technical Fest
#
# > **Target Audience**: Undergraduate/Graduate students, faculty, industry professionals, and the local tech community.
# > **Typical Duration**: 3–5 days (could be 2–3 if budget is tight).
# > **Key Success Factors**: Strong leadership, clear budget, diversified sponsorship, effective marketing, and seamless logistics.
#
# ---
#
# ### 1️⃣ Pre‑Planning Phase (Month – 4 weeks)
#
# | # | Task | Owner | Deliverable | Notes |
# |---|------|-------|-------------|-------|
# | 1 | **Form a Core Committee** | Student Council / College Admin | 4–6 core members (Executive Committee) | Roles: Chair, Treasurer, Marketing Lead, Operations Lead, Technical Lead, Guest/Faculty Liaison |
# | 2 | **Define Vision & Theme** | Exec Committee | Vision statement & theme (e.g., “AI for Social Good”) | Keeps branding cohesive |
# | 3 | **Create a Project Charter** | Chair | Document scope, objectives, constraints, risks | Approve by Department Head |
# | 4 | **Draft Initial Budget** | Treasurer | Rough estimate (venue, catering, tech, PR, contingencies) | Use previous fest data as baseline |
# | 5 | **Select Date & Venue** | Operations Lead | Finalized dates, venue availability & booking | Confirm with college administration |
# | 6 | **Kick‑off Meeting** | Chair | Agenda: roles, timelines, communication plan | Record minutes in shared drive |
#
# ---
#
# ### 2️⃣ Committee Expansion & Sub‑Teams (Week 3)
#
# | Sub‑Team | Head | Primary Responsibilities |
# |----------|------|---------------------------|
# | **Program** | Technical Lead | Workshops, Hackathon, Paper Presentations, Code‑off |
# | **Marketing & PR** | Marketing Lead | Social media, posters, press releases |
# | **Operations & Logistics** | Ops Lead | Venue layout, equipment, catering, transportation |
# | **Finance & Sponsorship** | Treasurer | Sponsorship proposals, budgeting, vendor contracts |
# | **Content & Communications** | Guest Lead | Guest lectures, alumni panel, student blogs |
# | **Volunteer Coordination** | Volunteer Lead | Recruitment, training, schedule |
# | **Safety & Compliance** | Safety Lead | COVID‑19 protocols, first aid, insurance |
# | **Tech Support** | IT Lead | Wi‑Fi, registration portal, live streaming |
#
# ---
#
# ### 3️⃣ Detailed Planning (Week 4–8)
#
# | Step | What to Do | Owner | Tools/Resources |
# |------|------------|-------|-----------------|
# | 3.1 | **Event Portfolio** | Program Lead | Draft list of 12–15 events (e.g., Robo‑Racing, Data‑Science Hackathon, IoT Demo) |
# | 3.2 | **Event Specifications** | Event Leads | Format, duration, required tech, judges, prizes |
# | 3.3 | **Budget Finalization** | Treasurer | Finalize cost per event, total budget, contingency (~10%) |
# | 3.4 | **Sponsorship Pitch Deck** | Sponsorship Lead | 5‑slide deck, tiered packages (Gold, Silver, Bronze), value propositions |
# | 3.5 | **Marketing Calendar** | Marketing Lead | Social media schedule, teaser videos, email blasts |
# | 3.6 | **Vendor & Supplier List** | Ops Lead | Audio/visual, catering, printing, security |
# | 3.7 | **Volunteer Training Manual** | Volunteer Lead | Roles, conduct code, emergency protocols |
# | 3.8 | **Legal & Compliance Checks** | Safety Lead | Insurance, liability waivers, data protection for registrations |
#
# ---
#
# ### 4️⃣ Execution Phase (Week 9–10 – 2 weeks before the fest)
#
# | Task | Owner | Deliverable |
# |------|-------|-------------|
# | 4.1 | **Confirm Sponsorships** | Sponsorship Lead | Signed contracts, logo placements |
# | 4.2 | **Finalize Venue Layout** | Ops Lead | Floor plan with event zones, signage, emergency exits |
# | 4.3 | **Set Up Registration Portal** | IT Lead | Online registration, badge printing |
# | 4.4 | **Print & Digital Collateral** | Marketing Lead | Posters, flyers, banner graphics |
# | 4.5 | **Technical Dry‑Run** | IT & Program Leads | Test Wi‑Fi, microphones, live streaming, AV equipment |
# | 4.6 | **Volunteer Orientation** | Volunteer Lead | Briefing, hand‑outs, schedule |
# | 4.7 | **Pre‑Event Press Release** | Marketing Lead | Media outreach, university newsletter |
# | 4.8 | **Safety Checklist** | Safety Lead | First‑aid kits, fire exits, medical staff on standby |
#
# ---
#
# ### 5️⃣ Execution Day(s)
#
# | Activity | Responsibility | Notes |
# |----------|----------------|-------|
# | **Morning Huddle** | Exec Committee | Quick status, last‑minute changes |
# | **Setup Finalization** | Ops & Volunteers | 2 hours before start |
# | **Opening Ceremony** | Chair | Welcome speech, sponsor acknowledgment |
# | **Event Flow** | Program Leads | Follow the master schedule |
# | **Live Streaming** | IT Lead | Manage streaming to YouTube/Instagram |
# | **Feedback Collection** | Volunteer Lead | Digital feedback forms, paper surveys |
# | **Closing Ceremony** | Chair | Prize distribution, thank‑you notes, social media recap |
# | **Debrief** | All | Record lessons learned, prepare final report |
#
# ---
#
# ### 6️⃣ Post‑Festival Wrap‑Up (Week 11–12)
#
# | Action | Owner | Deliverable |
# |--------|-------|-------------|
# | 6.1 | **Financial Reconciliation** | Treasurer | Final accounts, expense reports |
# | 6.2 | **Sponsor Thank‑You Letters** | Sponsorship Lead | PDF & printed thank‑you cards |
# | 6.3 | **Impact Report** | Program Lead | Attendance, participation metrics, media coverage |
# | 6.4 | **Volunteer Feedback** | Volunteer Lead | Survey results, recognition certificates |
# | 6.5 | **Lessons‑Learned Document** | Exec Committee | 10‑page report for future fests |
# | 6.6 | **Archive Materials** | IT Lead | All photos, videos, PDFs in cloud storage |
#
# ---
#
# ## 📌 Sample Timeline (4‑Month Calendar)
#
# | Month | Milestones |
# |-------|------------|
# | **Month 1** | Core Committee formed, vision/theme finalized, initial budget, venue booking. |
# | **Month 2** | Sub‑teams created, event portfolio drafted, sponsorship deck prepared. |
# | **Month 3** | Sponsorship outreach, marketing calendar finalized, vendor contracts signed, volunteer recruitment starts. |
# | **Month 4 (Week 1–2)** | Finalize schedule, technical dry‑run, printing, pre‑event press. |
# | **Month 4 (Week 3–4)** | Festival execution, closing, debrief, financial reconciliation. |
#
# ---
#
# ## 📊 Budget Snapshot (Example for 3‑Day Fest)
#
# | Category | Cost (₹) | Notes |
# |----------|----------|-------|
# | Venue & Stage | 1,50,000 | College auditorium + external stages |
# | Audio/Visual | 70,000 | Microphones, speakers, projectors |
# | Catering | 1,20,000 | 250 participants × 3 days |
# | Marketing | 50,000 | Posters, social media ads |
# | Prizes & Awards | 30,000 | Cash + trophies |
# | Sponsorships | 3,00,000 | Net after sponsorship income |
# | Logistics | 40,000 | Transport, security, cleaning |
# | Contingency (10%) | 90,000 | Unforeseen expenses |
# | **Total** | **6,50,000** | Net outlay after sponsorships: ₹3,50,000 |
#
# ---
#
# ## 📋 Key Checklists
#
# ### 1️⃣ Pre‑Event Checklist
#
# | Item | Done By | Status |
# |------|---------|--------|
# | Venue booked | Ops Lead | ✔︎ |
# | Sponsorships secured | Sponsorship Lead | ✔︎ |
# | Event schedule finalized | Program Lead | ✔︎ |
# | Registration portal live | IT Lead | ✔︎ |
# | Marketing assets ready | Marketing Lead | ✔︎ |
# | Volunteers trained | Volunteer Lead | ✔︎ |
# | Safety kit verified | Safety Lead | ✔︎ |
# | Technical equipment tested | IT Lead | ✔︎ |
#
# ### 2️⃣ Event‑Day Checklist
#
# | Time | Task | Owner |
# |------|------|-------|
# | 08:00 | Venue setup | Ops & Volunteers |
# | 10:00 | Sound check | IT |
# | 12:00 | Welcome speech | Chair |
# | 12:30 | First event | Program Lead |
# | 18:00 | Break & catering | Ops |
# | 20:00 | Closing ceremony | Chair |
# | 20:30

# %% [markdown]
# # 2C

# %%
from groq import Groq

client = Groq(
    api_key="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"
)

response = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role":"user",
            "content":"""
Question:
What is 25 × 18?

Show:

Thought
Action
Observation
Final Answer
"""
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# **Thought**
# We need to multiply 25 by 18.
# 25 × 18 can be broken into (25 × 10) + (25 × 8) for easier calculation.
#
# **Action**
# 1. Calculate 25 × 10 = 250.
# 2. Calculate 25 × 8 = 200.
# 3. Add the two results: 250 + 200 = 450.
#
# **Observation**
# The sum of the two partial products yields 450, confirming the multiplication is correct.
#
# **Final Answer**
# 25 × 18 = **450**

# %% [markdown]
# # 2D

# %%
from groq import Groq

client = Groq(
    api_key="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"
)

researcher = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role":"user",
            "content":"Research Agent: Explain Agentic AI."
        }
    ]
)

writer = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role":"user",
            "content":f"""
Writer Agent:
Create a report from:

{researcher.choices[0].message.content}
"""
        }
    ]
)

reviewer = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role":"user",
            "content":f"""
Reviewer Agent:
Improve this report:

{writer.choices[0].message.content}
"""
        }
    ]
)

print(reviewer.choices[0].message.content)
# Out:
# # Agentic AI – A Practical Guide to What It Is, Why It Matters, and How It Works
#
# *Prepared for executives, researchers, and practitioners who need a concise yet thorough understanding of agentic AI.*
#
# ---
#
# ## 1. Executive Summary
#
# **Agentic AI** is the class of artificial‑intelligence systems that act as *autonomous agents*: they sense the world, set and pursue their own objectives, learn from experience, and adapt over time.
# Unlike classic “tool” AIs (e.g., a spell‑checker or a recommendation engine that strictly follows a human‑defined algorithm), an agent can decide *what* to do, *why* it matters, and *how* to change its own behaviour.
#
# **Why the shift matters**
#
# | What agentic AI delivers | Why it matters |
# |--------------------------|----------------|
# | **Self‑improvement** (e.g., AlphaZero continually beats its own play) | Reduces the need for hand‑crafted rules |
# | **Robustness** in uncertain, open‑world settings | Enables deployment in real‑world, dynamic domains |
# | **Scalability** to thousands of concurrent users | Cuts per‑user cost for service‑providers |
# | **Human‑AI collaboration** (negotiation, co‑creation) | Enhances decision‑making in high‑stakes areas like medicine, finance, and design |
#
# Because these systems can *deviate* from a pre‑set script, safety, alignment, and governance become the central research priorities.
#
# ---
#
# ## 2. Core Concepts – The Agentic Stack
#
# | Term | What it means | Where you’ll see it |
# |------|---------------|---------------------|
# | **Agent** | A computational entity that perceives, chooses actions, and receives feedback. | Robotics, reinforcement learning, autonomous vehicles |
# | **Agency** | Intentionality + autonomy + goal‑directedness; the ability to *choose* a policy. | Planning, multi‑agent systems |
# | **Goal / Utility** | The objective the agent optimises (win a game, maximise profit, satisfy users). | Value‑alignment research |
# | **Autonomy** | Ability to act without constant human input, but *often* bounded by safety layers. | Driverless cars, household robots |
# | **Learning** | Updating internal models (policy, value, world model) based on experience. | Deep RL, continual learning |
# | **Safety & Alignment** | Ensuring that an agent’s behaviour stays consistent with human values and is safe in the real world. | AI safety, value‑alignment studies |
#
# ---
#
# ## 3. Why Agentic AI Matters
#
# | Benefit | Concrete Impact |
# |---------|-----------------|
# | **Self‑improvement** | Agents like AlphaZero improve from zero knowledge to grandmaster level without human guidance. |
# | **Robustness** | Autonomous drones can navigate changing weather or unexpected obstacles without re‑programming. |
# | **Scalability** | A single recommendation‑engine agent can serve millions of users while continuously updating its policy. |
# | **Human‑AI collaboration** | Clinical decision support agents negotiate treatment plans with doctors, blending data‑driven insight with professional judgement. |
#
# ---
#
# ## 4. Technical Foundations
#
# ### 4.1 Markov Decision Processes (MDPs) – The Formal Backbone
#
# | Symbol | Meaning | Example |
# |--------|---------|---------|
# | \(s\) | State | Current pose of a robot |
# | \(a\) | Action | “turn left” or “pick up object” |
# | \(P(s'|s,a)\) | Transition probability | Chance of slipping when walking on ice |
# | \(R(s,a)\) | Reward | +1 for reaching a goal, –0.1 per time step |
# | \(\pi(a|s)\) | Policy | Probability distribution over actions |
#
# **Goal** – Find \(\pi^*\) that maximises expected discounted return
# \[
# \mathbb{E}_{\pi}\!\left[\sum_{t=0}^{\infty}\gamma^t R_{t}\right].
# \]
#
# ### 4.2 Reinforcement Learning (RL) – How Agents Learn
#
# | Approach | Representative Algorithms | Strengths |
# |----------|--------------------------|-----------|
# | **Value‑based** | Q‑learning, Deep Q‑Network (DQN) | Stable convergence on discrete action spaces |
# | **Policy‑gradient** | REINFORCE, Actor‑Critic, PPO | Handles continuous control |
# | **Model‑based** | Dreamer, MuZero | Reduces sample complexity by simulating future |
# | **Hierarchical** | HRL, Option‑Critic | Breaks long‑horizon tasks into sub‑goals |
#
# ### 4.3 Planning & Model‑Based Reasoning
#
# * **Tree search** – A*, MCTS (used by AlphaZero).
# * **Planning as inference** – Treats action sequencing as probabilistic inference.
# * **Meta‑planning** – Agents decide *how* to learn, not only *what* to do.
#
# ### 4.4 Multi‑Agent Dynamics
#
# | Type | Interaction | Typical use‑case |
# |------|-------------|-----------------|
# | Cooperative | Shared reward / joint policy | Swarm robotics, distributed sensor networks |
# | Competitive | Adversarial games | Chess, Go, autonomous negotiation |
# | Mixed‑Motivation | Cooperation + competition | Market simulations, collaborative manufacturing |
#
# ### 4.5 Embodied & Simulated Agents
#
# | Domain | Example | Agentic Features |
# |--------|---------|-----------------|
# | **Robotics** | Boston Dynamics Spot | Continuous perception, real‑time planning |
# | **Simulation** | MuJoCo environments | Rapid iteration, safety‑aware exploration |
# | **Digital Twins** | Autonomous maintenance bots | Predictive maintenance, adaptive scheduling |
#
# ---
#
# ## 5. Illustrative Examples
#
# | Domain | Agentic System | Agency Highlights |
# |--------|----------------|-------------------|
# | **Game Playing** | AlphaZero, MuZero | Learns from scratch, self‑directed exploration |
# | **Robotics** | Atlas, Spot | Autonomously navigates dynamic environments |
# | **NLP** | GPT‑4 (instruction‑following) | Generates context‑aware replies, adapts across sessions |
# | **Autonomous Vehicles** | Waymo, Tesla Autopilot | Real‑time perception + planning, continual learning |
# | **Recommender Engines** | Spotify, Netflix | Updates preference models on‑the‑fly |
# | **Finance** | Algorithmic trading bots | Executes buy/sell decisions to maximise portfolio return |
# | **Healthcare** | AI diagnostic assistants | Suggests treatments, learns from outcomes |
#
# ---
#
# ## 6. Agentic AI vs. Tool AI
#
# | Feature | Agentic AI | Tool AI |
# |---------|------------|---------|
# | **Goal‑Setting** | Sets and revises sub‑goals | Follows a fixed human‑defined script |
# | **Autonomy** | Operates with minimal oversight | Requires explicit commands |
# | **Adaptation** | Learns from experience | Fixed until retrained |
# | **Misalignment Risk** | Higher (unintended behaviours) | Lower (direct human intent) |
# | **Typical Uses** | Autonomous drones, AI advisers | Text editors, calculators |
#
# ---
#
# ## 7. Safety, Alignment, and Governance
#
# | Challenge | Why It Matters | Mitigation Tactics |
# |-----------|----------------|--------------------|
# | **Goal Misalignment** | Reward hacking, unintended objectives | Reward‑modeling, inverse RL, human‑in‑the‑loop |
# | **Exploration Risk** | Unpredictable actions during learning | Safe RL, constrained exploration, curriculum learning |
# | **Manipulation** | Agents influencing humans to meet goals | Transparency layers, explainable policies |
# | **Adversarial Environments** | Environments that exploit agent weaknesses | Robustness training, adversarial RL |
# | **Complexity & Scalability** | Verification becomes infeasible as systems grow | Modular design, formal verification, large‑scale simulation |
#
# ---
#
# ## 8. Current Research Trends
#
# | Trend | Key Questions |
# |-------|----------------|
# | **Self‑Improving Agents** | How to make agents continually learn without catastrophic forgetting? |
# | **Hierarchical & Symbolic Planning** | Combining deep RL with symbolic reasoning for complex tasks |
# | **Explainable Agency** | Making policy choices interpretable to users |
# | **Human‑AI Negotiation** | Designing protocols for fair trade‑offs between agent and human preferences |
# | **Safety‑First RL** | Guaranteeing safety constraints during online learning |
# | **Ethical & Governance Models** | Crafting regulations, industry standards, and

# %% [markdown]
# # 2E

# %%
# ==========================================================
# REWOO PATTERN USING GROQ
# Reasoning Without Observation
# ==========================================================

from groq import Groq

client = Groq(
    api_key="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"
)

user_query = """
Create a report about Artificial Intelligence.
"""

# --------------------------------------------------
# STEP 1: PLAN FIRST
# --------------------------------------------------

planner = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role":"user",
            "content":f"""
You are a Planner Agent.

For the task below:

{user_query}

Create a step-by-step plan.

Do NOT execute.
Only generate the plan.
"""
        }
    ]
)

plan = planner.choices[0].message.content

print("\n========== GENERATED PLAN ==========\n")
print(plan)

# --------------------------------------------------
# STEP 2: EXECUTE PLAN
# --------------------------------------------------

executor = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role":"user",
            "content":f"""
Execute the following plan:

{plan}

Generate the final report.
"""
        }
    ]
)

result = executor.choices[0].message.content

print("\n========== FINAL OUTPUT ==========\n")
print(result)
# Out:
# ========== GENERATED PLAN ==========
#
# ## Step‑by‑Step Plan: Creating a Report on Artificial Intelligence
#
# | # | Task | Deliverable | Resources Needed | Time Estimate | Notes |
# |---|------|-------------|------------------|---------------|-------|
# | 1 | **Define Purpose & Audience** | Clear statement of report goals (e.g., educational, executive briefing, technical review) and target readership (students, industry professionals, policymakers). | None | 30 min | Determines depth, tone, and format. |
# | 2 | **Set Scope & Focus Areas** | List of AI sub‑topics to cover (history, fundamentals, machine learning, deep learning, NLP, robotics, ethics, industry applications, future trends, policy). | None | 1 h | Avoid over‑breadth; choose 4‑6 core sections. |
# | 3 | **Develop Outline** | Hierarchical structure: introduction, background, core sections, case studies, challenges, recommendations, conclusion, references, appendices. | Spreadsheet/word doc | 1 h | Use a mind‑map or outline tool to keep track of sub‑headings. |
# | 4 | **Create Research Plan** | Identify primary & secondary sources: academic journals, industry reports, reputable news outlets, books, whitepapers. List at least 15 sources per major section. | Google Scholar, IEEE Xplore, industry sites | 2 h | Prioritize peer‑reviewed content for credibility. |
# | 5 | **Collect Sources & Take Notes** | Download PDFs, save URLs, annotate key points, note authorship, date, methodology. Use citation manager (Zotero, Mendeley). | Computer, internet, citation tool | 4–6 h | Tag sources by section for quick retrieval. |
# | 6 | **Draft Executive Summary** | One‑page concise overview of findings, key insights, and recommendations. | Outline, key notes | 1 h | Write after completing first draft of main body. |
# | 7 | **Write Section Drafts** | Complete first pass of each section (introduction, history, fundamentals, sub‑topics, case studies, challenges, recommendations). | Outline, notes, citation manager | 8–10 h | Aim for ~1,200‑1,500 words per major section. |
# | 8 | **Insert Visuals & Tables** | Add charts, graphs, diagrams, and tables to illustrate data (e.g., AI adoption rates, performance metrics). | PowerPoint/Visio, Excel | 2–3 h | Ensure all visuals are properly labeled and sourced. |
# | 9 | **Cite Sources & Compile Bibliography** | Use appropriate citation style (APA, IEEE, Chicago). Generate reference list. | Citation manager export | 1 h | Double‑check in‑text citations match bibliography. |
# | 10 | **First Review & Self‑Edit** | Read for clarity, flow, logical consistency. Check for jargon, define terms. | Self, style guide | 2 h | Use tools like Grammarly, Hemingway for style. |
# | 11 | **Peer / Expert Review** | Share draft with 2‑3 subject matter experts or colleagues. Gather feedback on technical accuracy and readability. | Email/ collaboration platform | 1–2 days | Allocate time for revisions after feedback. |
# | 12 | **Revise & Polish** | Incorporate feedback, refine arguments, tighten prose, correct typos. | Draft, feedback notes | 3–4 h | Maintain original voice while enhancing clarity. |
# | 13 | **Formatting & Final Checks** | Apply formatting guidelines (font, margins, heading styles). Verify page numbers, headers, footers. | Word/Google Docs | 1 h | Ensure compliance with any institutional or publication standards. |
# | 14 | **Proofreading** | Final read‑through for grammar, punctuation, and consistency. | Proofreader tool or human editor | 1 h | Check for any remaining errors or formatting glitches. |
# | 15 | **Prepare Deliverables** | Export to PDF, create any supplementary materials (appendices, glossary). | Export function | 30 min | Verify PDF integrity on multiple devices. |
# | 16 | **Submit / Publish** | Deliver report to intended recipient or upload to platform. | Email, LMS, website | 30 min | Confirm receipt and accessibility. |
# | 17 | **Post‑Publication Review** | Collect feedback from readers, note areas for future updates. | Feedback forms, analytics | Ongoing | Use insights for subsequent reports. |
#
# ### Timeline (Approximate)
#
# | Phase | Duration | Start | End |
# |-------|----------|-------|-----|
# | Planning & Scope | 2 h | Day 1 | Day 1 |
# | Research | 8–10 h | Day 1 | Day 2 |
# | Writing Draft | 12–14 h | Day 2 | Day 3 |
# | Review & Revision | 8–10 h | Day 4 | Day 5 |
# | Finalization | 2–3 h | Day 5 | Day 5 |
# | Submission | 1 h | Day 5 | Day 5 |
#
# > **Total Estimated Time:** ~40 hours over 5 working days.
#
# Feel free to adjust the schedule or scope based on project constraints, audience needs, or available resources.
#
# ========== FINAL OUTPUT ==========
#
# # Report on Artificial Intelligence
# **Prepared for:** Industry Professionals & Policymakers
# **Prepared by:** [Your Name / Your Organization]
# **Date:** 27 August 2026
#
# ---
#
# ## Table of Contents
#
# | Section | Page |
# |---------|------|
# | Executive Summary | 1 |
# | 1. Introduction | 2 |
# | 2. History of AI | 3 |
# | 3. Technical Foundations | 4 |
# | 3.1. Machine Learning | 4 |
# | 3.2. Deep Learning | 5 |
# | 3.3. Natural Language Processing | 6 |
# | 3.4. Robotics & Perception | 7 |
# | 4. Industry Applications | 8 |
# | 4.1. Healthcare | 8 |
# | 4.2. Finance | 9 |
# | 4.3. Manufacturing | 10 |
# | 4.4. Public Sector | 11 |
# | 5. Ethical & Societal Considerations | 12 |
# | 6. Future Trends & Emerging Paradigms | 13 |
# | 7. Challenges & Risks | 14 |
# | 8. Policy & Regulatory Recommendations | 15 |
# | 9. Conclusion | 16 |
# | References | 17 |
# | Appendices | 18 |
# |   A. Glossary | 18 |
# |   B. Key Data Tables | 19 |
#
# *(Page numbers are illustrative; adjust when formatting.)*
#
# ---
#
# ## Executive Summary (1 page)
#
# Artificial Intelligence (AI) has evolved from a niche research field to a transformative force reshaping every sector of the economy. This report provides a comprehensive overview of AI’s technical underpinnings, key industry applications, ethical dilemmas, and emerging trends, culminating in actionable policy recommendations for stakeholders.
#
# **Key Findings**
#
# | Finding | Implication |
# |---------|-------------|
# | AI adoption rose from 5 % of enterprises in 2015 to 32 % in 2023, with healthcare and finance leading the charge. | Companies that integrate AI early gain a competitive edge in efficiency and innovation. |
# | Machine‑learning models now exceed human performance in image recognition, speech translation, and predictive analytics. | Workforce skill gaps must be addressed; reskilling programs are essential. |
# | Ethical concerns—bias, transparency, accountability—are most pronounced in high‑stakes domains such as criminal justice and credit scoring. | Regulatory frameworks should prioritize explainability and bias mitigation. |
# | Emerging paradigms—foundation models, neuromorphic computing, and quantum‑accelerated inference—promise exponential gains but introduce new security and governance challenges. | Investment in research & development (R&D) and public‑private partnerships is critical. |
# | The global AI talent pool is uneven; advanced economies hold 70 % of AI‑qualified professionals, creating a risk of “AI‑technological imperialism.” | International cooperation and capacity‑building initiatives are needed. |
#
# **Recommendations**
#
# 1. **Establish a National AI Governance Board** that coordinates standards, ethics, and workforce development.
# 2. **Mandate Explainability for AI Systems in Public Services** (e.g., health, transport, justice).
# 3. **Create Incentives for SMEs to Adopt AI** via tax credits, grants, and shared‑risk pilots.
# 4. **Invest in AI Education** at all levels, emphasizing data literacy and ethical reasoning.
# 5. **Develop Cross‑Border Data Sharing Agreements** that respect privacy while enabling AI innovation.
#
# By aligning policy with industry needs and ethical imperatives, stakeholders can harness AI’s benefits while mitigating its risks.
#
# ---
#
# ## 1. Introduction
#
# Artificial Intelligence—defined as systems that exhibit intelligent behavior such as perception, reasoning, learning, and decision‑making—has become a central pillar of modern innovation. The last decade has witnessed a convergence of advanced algorithms, abundant data, and unprecedented compute power, enabling AI to move from laboratory prototypes to commercial products that touch everyday life.
#
# This report examines AI from multiple angles: its historical development, core technical concepts, sectoral applications, ethical considerations, future directions, and policy implications. The target audience includes industry leaders, policymakers, and other stakeholders who must navigate the opportunities and challenges presented by AI.
#
# ---
#
# ## 2. History of AI
#
# | Era | Milestones | Impact |
# |-----|------------|--------|
# | **1950‑1960s – Symbolic AI** | Logic‑based systems (Logic Theorist, ELIZA). | Early successes in problem solving and natural‑language interactions; set groundwork for knowledge representation. |
# | **1970‑1980s – Expert Systems** | MYCIN, XCON. | Demonstrated commercial viability in medical diagnosis and configuration tasks; highlighted brittleness and knowledge acquisition costs. |
# | **1990‑2000s – Machine Learning & Data‑Driven AI** | Support Vector Machines, decision trees; first AI victories in chess and Go. | Shift from hand‑crafted rules to data‑driven models; increased robustness and scalability. |
# | **2010‑present – Deep Learning & Big Data** | CNNs (AlexNet), RNNs, transformer models; GPT‑3, BERT. | Achieved breakthroughs in vision, language, and multimodal AI; democratized AI via cloud APIs and open‑source frameworks. |
# | **2020‑present – Foundation Models & Responsible AI** | GPT‑4, Claude, Llama 2. | Introduced large‑scale, generalist models; sparked discussions on alignment, safety, and governance. |
#
# Key turning points: the “AI Winter” periods (mid‑80s, early‑2000s) underscored the need for realistic expectations, while the resurgence in the 2010s highlighted the transformative potential of data‑rich, compute‑intensive models.
#
# ---
#
# ## 3. Technical Foundations
#
# ### 3.1 Machine Learning
#
# - **Definition**: Algorithms that infer patterns from data and improve performance over time.
# - **Key Techniques**: Supervised learning (regression, classification), unsupervised learning (clustering, dimensionality reduction), reinforcement learning (policy optimization).
# - **Representative Algorithms**: Random Forests, Support Vector Machines, k‑Nearest Neighbors.
# - **Applications**: Fraud detection, recommendation engines, predictive maintenance.
#
# ### 3.2 Deep Learning
#
# - **Definition**: Neural networks with multiple hidden layers that learn hierarchical representations.
# - **Core Architectures**: Convolutional Neural Networks (CNNs) for vision; Recurrent Neural Networks (RNNs), Transformers for sequence modeling.
# - **Training Paradigms**: Supervised, self‑supervised, transfer learning.
# - **Performance Drivers**: GPU/TPU acceleration, large datasets, parallelized training.
#
# ### 3.3 Natural Language Processing (NLP)
#
# - **Evolution**: From rule‑based parsing to statistical models (n‑grams) to deep learning (word embeddings, transformers).
# - **Key Models**: BERT, GPT‑n, T5, LLaMA.
# - **Tasks**: Sentiment analysis, machine translation, summarization, dialogue systems.
# - **Challenges**: Contextual nuance, bias amplification, hallucinations.
#
# ### 3.4 Robotics & Perception
#
# - **Sensor Fusion**: LIDAR, radar, cameras, depth sensors integrated via SLAM (Simultaneous Localization and Mapping).
# - **Control**: Model Predictive Control (MPC), reinforcement learning for locomotion.
# - **Applications**: Autonomous vehicles, warehouse automation, surgical robots.
#
# ---
#
# ## 4. Industry Applications
#
# ### 4.1 Healthcare
#
# | Application | Impact | Example |
# |-------------|--------|---------|
# | **Diagnostic imaging** | Improves early detection of diseases. | AI‑assisted radiology (e.g., AI‑detected lung nodules). |
